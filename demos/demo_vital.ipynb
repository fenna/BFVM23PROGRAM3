# %%
import vitaldb

# %%
path = "data/4347.vital"
tracknames = vitaldb.vital_trks(path) 
tracknames
# Out:
# ['SNUADC/ART',
#  'SNUADC/ECG_II',
#  'Solar8000/HR',
#  'Solar8000/ST_II',
#  'Solar8000/ART_MBP',
#  'Solar8000/ART_SBP',
#  'Solar8000/ART_DBP',
#  'Solar8000/CVP',
#  'Solar8000/PLETH_SPO2',
#  'Solar8000/PLETH_HR',
#  'Solar8000/ETCO2',
#  'Solar8000/INCO2',
#  'Solar8000/RR_CO2',
#  'Solar8000/FEO2',
#  'Solar8000/FIO2',
#  'Solar8000/VENT_INSP_TM',
#  'Solar8000/VENT_RR',
#  'Solar8000/VENT_MV',
#  'Solar8000/VENT_TV',
#  'Solar8000/VENT_PIP',
#  'Solar8000/VENT_PPLAT',
#  'Solar8000/VENT_MAWP',
#  'Solar8000/RR',
#  'Solar8000/GAS2_AGENT',
#  'Solar8000/GAS2_EXPIRED',
#  'Solar8000/GAS2_INSPIRED',
#  'Primus/CO2',
#  'Primus/AWP',
#  'Primus/COMPLIANCE',
#  'Primus/INSP_SEVO',
#  'Primus/EXP_SEVO',
#  'Primus/PAMB_MBAR',
#  'Primus/MAWP_MBAR',
#  'Primus/PPLAT_MBAR',
#  'Primus/PEEP_MBAR',
#  'Primus/PIP_MBAR',
#  'Primus/TV',
#  'Primus/MAC',
#  'Primus/VENT_LEAK',
#  'Primus/MV',
#  'Primus/RR_CO2',
#  'Primus/FLOW_N2O',
#  'Primus/FLOW_AIR',
#  'Primus/FLOW_O2',
# ...

# %%
interval=2
tracks = ['Solar8000/PLETH_HR', 'Solar8000/PLETH_SPO2', 'EVENT']
df = vitaldb.vital_recs(path, 
                        track_names=tracks, 
                        interval=interval, 
                        return_timestamp=True, 
                        return_datetime=True, 
                        return_pandas=True)
df.info()
df['Solar8000/PLETH_HR'][0:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14400 entries, 0 to 14399
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  14400 non-null  datetime64[ns, UTC]
#  1   Solar8000/PLETH_HR    13843 non-null  object
#  2   Solar8000/PLETH_SPO2  13843 non-null  object
#  3   EVENT                 4 non-null      object
# dtypes: datetime64[ns, UTC](1), object(3)
# memory usage: 450.1+ KB
# 0     NaN
# 1     NaN
# 2    84.0
# 3    83.0
# 4    84.0
# 5    84.0
# 6    85.0
# 7    86.0
# 8    86.0
# 9    86.0
# Name: Solar8000/PLETH_HR, dtype: object

# %%
set(df['EVENT'])
# Out:
# {'Case finished', 'Case started', 'Surgery finished', 'Surgery started', nan}
